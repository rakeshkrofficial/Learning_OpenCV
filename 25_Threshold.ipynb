# %%
import cv2

# %%
img = cv2.imread("C:/Users/rakes/Documents/Machine Learning/Images/img1.png")
img = cv2.resize(img,(500,470))

_ , th = cv2.threshold(img,200,255,cv2.THRESH_BINARY)

cv2.imshow("image",img)
cv2.imshow("Threshold",th)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.threshold??
# Out:
# Docstring:
# threshold(src, thresh, maxval, type[, dst]) -> retval, dst
# .   @brief Applies a fixed-level threshold to each array element.
# .
# .   The function applies fixed-level thresholding to a multiple-channel array. The function is typically
# .   used to get a bi-level (binary) image out of a grayscale image ( #compare could be also used for
# .   this purpose) or for removing a noise, that is, filtering out pixels with too small or too large
# .   values. There are several types of thresholding supported by the function. They are determined by
# .   type parameter.
# .
# .   Also, the special values #THRESH_OTSU or #THRESH_TRIANGLE may be combined with one of the
# .   above values. In these cases, the function determines the optimal threshold value using the Otsu's
# .   or Triangle algorithm and uses it instead of the specified thresh.
# .
# .   @note Currently, the Otsu's method is implemented only for CV_8UC1 and CV_16UC1 images,
# ...

# %%
img = cv2.imread("C:/Users/rakes/Documents/Machine Learning/Images/img.png")
img = cv2.resize(img,(500,470))


_ , th = cv2.threshold(img,200,255,cv2.THRESH_BINARY)

cv2.imshow("image",img)
cv2.imshow("Threshold",th)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("C:/Users/rakes/Documents/Machine Learning/Images/img.png")
img = cv2.resize(img,(500,470))
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

_ , th = cv2.threshold(img,130,255,cv2.THRESH_BINARY)

cv2.imshow("image",img)
cv2.imshow("Threshold",th)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("C:/Users/rakes/Documents/Machine Learning/Images/img.png")
img = cv2.resize(img,(500,470))
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

_ , th = cv2.threshold(img,130,255,cv2.THRESH_BINARY_INV)

cv2.imshow("image",img)
cv2.imshow("Threshold",th)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("C:/Users/rakes/Documents/Machine Learning/Images/img.png")
img = cv2.resize(img,(500,470))
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

_ , th = cv2.threshold(img,170,255,cv2.THRESH_MASK)

cv2.imshow("image",img)
cv2.imshow("Threshold",th)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("C:/Users/rakes/Documents/Machine Learning/Images/img.png")
img = cv2.resize(img,(500,470))
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

_ , th = cv2.threshold(img,170,255,cv2.THRESH_TRIANGLE)

cv2.imshow("image",img)
cv2.imshow("Threshold",th)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("C:/Users/rakes/Documents/Machine Learning/Images/img.png")
img = cv2.resize(img,(500,470))
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

_ , th = cv2.threshold(img,170,255,cv2.THRESH_TOZERO)

cv2.imshow("image",img)
cv2.imshow("Threshold",th)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("C:/Users/rakes/Documents/Machine Learning/Images/img.png")
img = cv2.resize(img,(500,470))
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

_ , th = cv2.threshold(img,170,255,cv2.THRESH_TOZERO_INV)

cv2.imshow("image",img)
cv2.imshow("Threshold",th)

cv2.waitKey(0)
cv2.destroyAllWindows()
