# %%
import cv2

# %%
img = cv2.imread("C:/Users/rakes/Documents/Machine Learning/Images/download_3.jpg")

print(img)   # bgr  -> (0-255,0-255,0-255)
# Out:
# [[[ 54  49  48]
#   [ 34  26  26]
#   [ 58  45  43]
#   ...
#   [ 94 115 112]
#   [112 136 126]
#   [154 178 166]]
#
#  [[ 54  49  48]
#   [ 35  27  27]
#   [ 52  39  37]
#   ...
#   [ 84 105 102]
#   [101 125 115]
#   [135 159 147]]
#
#  [[ 60  55  54]
#   [ 47  39  39]
#   [ 55  42  40]
#   ...
#   [ 86 105 102]
#   [ 94 115 106]
#   [112 134 122]]
#
#  ...
#
#  [[ 37  38  42]
#   [ 28  31  35]
#   [ 29  34  37]
#   ...
#   [ 46  76  93]
#   [ 42  72  89]
#   [ 48  78  95]]
#
#  [[ 34  37  41]
#   [ 24  27  31]
#   [ 31  36  39]
#   ...
#   [ 79 109 128]
#   [ 64  94 113]
#   [ 48  80  99]]
#
#  [[ 31  34  38]
#   [ 21  24  28]
#   [ 32  37  40]
#   ...
#   [ 69  99 118]
#   [ 65  97 116]
#   [ 56  88 107]]]

# %%
img.shape
# Out:
# (128, 192, 3)

# %%
re_size= cv2.resize(img,(300,250))
re_size.shape
# Out:
# (250, 300, 3)

# %%
cv2.imshow("old image",img)
cv2.imshow("new image", re_size)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("C:/Users/rakes/Documents/Machine Learning/Images/download_4.jpg",0) 

print(img.shape)

cv2.imshow("Image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (138, 192)
