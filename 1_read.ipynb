# %%
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread("C:/Users/rakes/Documents/Machine Learning/OpenCV/Beach_tourist.png")  # image read
cv2.imshow("Image",img)    # image show
cv2.waitKey(0)           # image frame wait  (time-ms)  and 0 pass keyboard any key press
cv2.destroyAllWindows() # all windows close
# cv2.destroyWindow("image_name")      # only one window close

# %%
img = cv2.imread("C:/Users/rakes/Documents/Machine Learning/OpenCV/Beach_tourist.png")  # image read
cv2.imshow("Image1",img)    # image show
cv2.imshow("Image2",img)
cv2.waitKey(10000)           # image frame wait  (time-ms)  and 0 pass keyboard any key press
# cv2.destroyAllWindows() # all windows close
cv2.destroyWindow("Image2")      # only one window close

cv2.waitKey(10000)
cv2.destroyWindow("Image1")
