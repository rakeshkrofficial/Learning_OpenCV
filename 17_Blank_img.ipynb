# %%
import cv2
import numpy as np

# %%
img = cv2.imread("C:/Users/rakes/Documents/Machine Learning/Images/WhatsApp.jpeg")
img = cv2.resize(img,(400,430))

new_img = np.ones((400,430,3),np.uint8)*255


cv2.imshow("image",img)
cv2.imshow("New image",new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
new_img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
img = cv2.imread("C:/Users/rakes/Documents/Machine Learning/Images/WhatsApp.jpeg")
img = cv2.resize(img,(400,430))

blk = np.zeros((400,430),np.uint8)

cv2.imshow("image",img)
cv2.imshow("new Image",blk)

cv2.waitKey(0)
cv2.destroyAllWindows()
