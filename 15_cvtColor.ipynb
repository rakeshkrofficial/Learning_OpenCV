# %%
import cv2

# %%
org = cv2.imread("C:/Users/rakes/Documents/Machine Learning/Images/download_6.png")
org = cv2.resize(org,(500,500))

new = cv2.cvtColor(org,cv2.COLOR_BGR2HLS)

cv2.imshow("orginal",org)
cv2.imshow("new",new)

cv2.waitKey(0)
cv2.destroyAllWindows()
