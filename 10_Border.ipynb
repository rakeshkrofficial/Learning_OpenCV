# %%
import cv2
import numpy as np

# %%
img = cv2.imread("C:/Users/rakes/Documents/Machine Learning/Images/download_1.jpg")
re_img = cv2.resize(img, (300,300))

img1 = cv2.copyMakeBorder(re_img,10,10,20,20,cv2.BORDER_CONSTANT,None, value =2)


cv2.imshow("Image",img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("C:/Users/rakes/Documents/Machine Learning/Images/download_1.jpg")
re_img = cv2.resize(img, (300,300))

img1 = cv2.copyMakeBorder(re_img,10,10,20,20,cv2.BORDER_ISOLATED)


cv2.imshow("Image",img1)
cv2.waitKey(0)
cv2.destroyAllWindows()
