# %%
import cv2
import numpy as np

# %%
img = cv2.imread("C:/Users/rakes/Documents/Machine Learning/Images/download_6.png")
img = cv2.resize(img,(500,400))

# img[y1:y2 , x1:x2]

crop = img[152:180, 200:300]

cv2.imshow("IMAGE",img)
cv2.imshow("Crop",crop)
    
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img
# Out:
# array([[[ 82, 140, 224],
#         [ 82, 140, 224],
#         [ 82, 140, 224],
#         ...,
#         [ 53,  67, 108],
#         [ 78,  68,  79],
#         [ 93,  74,  61]],
#
#        [[ 82, 140, 224],
#         [ 82, 140, 224],
#         [ 82, 140, 224],
#         ...,
#         [ 62,  68, 102],
#         [ 85,  71,  74],
#         [ 99,  77,  57]],
#
#        [[ 82, 140, 224],
#         [ 82, 140, 224],
#         [ 82, 140, 224],
#         ...,
#         [ 73,  70,  93],
#         [ 95,  76,  66],
#         [108,  82,  49]],
#
#        ...,
#
#        [[  0,   5,  16],
#         [  0,   5,  16],
#         [  0,   5,  16],
#         ...,
#         [ 11,   8,  11],
#         [ 12,   9,  12],
#         [ 12,  10,  12]],
#
#        [[  0,   4,  15],
#         [  0,   4,  15],
#         [  0,   5,  16],
#         ...,
#         [ 10,   7,  10],
#         [ 12,   9,  12],
#         [ 12,  10,  12]],
#
#        [[  0,   4,  15],
#         [  0,   4,  15],
#         [  0,   4,  15],
#         ...,
#         [ 11,   8,  11],
#         [ 12,   9,  12],
#         [ 12,  10,  12]]], shape=(400, 500, 3), dtype=uint8)

# %%
crop.shape
# Out:
# (340, 300, 3)
