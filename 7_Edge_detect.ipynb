# %%
import cv2

# %%
img = cv2.imread("C:/Users/rakes/Documents/Machine Learning/Images/download_7.jpg")
img =cv2.resize(img, (350,350))

new_img = cv2.Canny(img,200,210,apertureSize = 5, L2gradient = True)

cv2.imshow("original",img)
cv2.imshow("Egde",new_img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
print(img.shape)
print(new_img.shape)
# Out:
# (350, 350, 3)
# (350, 350)
