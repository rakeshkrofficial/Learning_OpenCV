# %%
import cv2
import numpy as np

# %%
img = cv2.imread("C:/Users/rakes/Documents/Machine Learning/Images/WhatsApp.jpeg")
img = cv2.resize(img,(700,430))

crop = img[125:246,195:368]

img[125:246,368:541] = crop # right
img[125:246,527:700] = crop  # right
img[125:246,22:195] = crop  # left

cv2.imwrite("save.png",img)

cv2.imshow("image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("save.png")
crop = img[125:246,187:368]

cv2.imshow("crop",crop)
cv2.waitKey(0)
cv2.destroyAllWindows()
