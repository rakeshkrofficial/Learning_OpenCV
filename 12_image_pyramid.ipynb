# %%
import cv2
import numpy as np

# %%
img = cv2.imread("C:/Users/rakes/Documents/Machine Learning/Images/download_6.png")
# img = cv2.resize(img,(500,500))


cv2.imshow("image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("C:/Users/rakes/Documents/Machine Learning/Images/download_6.png")
print(img.shape)

new_img = cv2.pyrDown(img)
print(new_img.shape)

new_img1 = cv2.pyrDown(new_img)
print(new_img1.shape)

cv2.imshow("image",img)
cv2.imshow("new Image",new_img)
cv2.imshow("Third Image",new_img1)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (1080, 1920, 3)
# (540, 960, 3)
# (270, 480, 3)

# %%
big_img = cv2.pyrUp(new_img1)
print(big_img.shape)

cv2.imshow("Image",new_img1)
cv2.imshow("Big image", big_img)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (540, 960, 3)
